# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras import optimizers

training_data = np.array([[0,0], [0,1], [1,0], [1,1]], "float32")
target_data = np.array([[0], [1], [1], [0]], "float32")

model =Sequential()
model.add(Dense(4, input_dim=2, activation= "sigmoid"))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = optimizers.Adam(learning_rate = 0.1), metrics = ['binary_accuracy'])

model.fit(training_data, target_data, epochs = 1000, verbose = 2)

print(model.predict(training_data))
print('\n Accuracy: %4f' %(model.evaluate(training_data, target_data)[1]))
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/1000
# 1/1 - 1s - 779ms/step - binary_accuracy: 0.5000 - loss: 0.6941
# Epoch 2/1000
# 1/1 - 0s - 35ms/step - binary_accuracy: 0.5000 - loss: 0.6999
# Epoch 3/1000
# 1/1 - 0s - 35ms/step - binary_accuracy: 0.5000 - loss: 0.6926
# Epoch 4/1000
# 1/1 - 0s - 38ms/step - binary_accuracy: 0.5000 - loss: 0.6890
# Epoch 5/1000
# 1/1 - 0s - 38ms/step - binary_accuracy: 0.5000 - loss: 0.6896
# Epoch 6/1000
# 1/1 - 0s - 41ms/step - binary_accuracy: 0.5000 - loss: 0.6869
# Epoch 7/1000
# 1/1 - 0s - 41ms/step - binary_accuracy: 0.5000 - loss: 0.6819
# Epoch 8/1000
# 1/1 - 0s - 40ms/step - binary_accuracy: 0.7500 - loss: 0.6781
# Epoch 9/1000
# 1/1 - 0s - 39ms/step - binary_accuracy: 0.7500 - loss: 0.6756
# Epoch 10/1000
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras import optimizers

data = np.loadtxt('Data/data-03-diabetes.csv', delimiter=',')

seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

x_train = data[:, 0:8]
y_train = data[:, [8]]

model =Sequential()
model.add(Dense(30, input_dim=8, activation= "relu"))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = optimizers.Adam(learning_rate = 0.01), metrics = ['binary_accuracy'])

model.fit(x_train, y_train, epochs = 500, verbose = 2)

print(model.predict(x_train))
print('\n Accuracy: %4f' %(model.evaluate(x_train, y_train)[1]))
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\dong\miniconda3\envs\ai\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 24/24 - 1s - 38ms/step - binary_accuracy: 0.6350 - loss: 0.6135
# Epoch 2/500
# 24/24 - 0s - 3ms/step - binary_accuracy: 0.7602 - loss: 0.5195
# Epoch 3/500
# 24/24 - 0s - 3ms/step - binary_accuracy: 0.7628 - loss: 0.4795
# Epoch 4/500
# 24/24 - 0s - 3ms/step - binary_accuracy: 0.7602 - loss: 0.4705
# Epoch 5/500
# 24/24 - 0s - 3ms/step - binary_accuracy: 0.7549 - loss: 0.4665
# Epoch 6/500
# ...

# %%
class_0_data = data[data[:, -1] == 0]
x_data_0 = class_0_data[:, 0:-1]
y_data_0 = class_0_data[:, [-1]]

# Class가 1인 데이터만 필터링 (마지막 열이 1인 행만 추출)
class_1_data = data[data[:, -1] == 1]
x_data_1 = class_1_data[:, 0:-1]
y_data_1 = class_1_data[:, [-1]]

# Class 0 평가
print("\n[ Class 0 (음성) 데이터 평가 결과 ]")
print(model.evaluate(x_data_0, y_data_0))

# Class 1 평가
print("\n[ Class 1 (양성) 데이터 평가 결과 ]")
print(model.evaluate(x_data_1, y_data_1))
# Out:
# [ Class 0 (음성) 데이터 평가 결과 ]
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - binary_accuracy: 0.7376 - loss: 0.5253
# [0.5252991318702698, 0.7376425862312317]
#
# [ Class 1 (양성) 데이터 평가 결과 ]
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.9657 - loss: 0.1178
# [0.11778257042169571, 0.9657257795333862]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Input
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from mpl_toolkits.mplot3d import Axes3D

data = np.loadtxt('Data/Blood_fat.csv', delimiter = ',')

X = np.array(data[:,0:2], dtype=np.float32)
Y = np.array(data[:,2], dtype=np.float32)
Y = Y.reshape(25, 1)

rmsprop = RMSprop(learning_rate = 0.01)
model = Sequential()
model.add(Input(shape = (2,)))
model.add(Dense(1))
model.compile(loss = 'mse', optimizer = rmsprop)
model.summary
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# <bound method Model.summary of <Sequential name=sequential_1, built=True>>

# %%
hist = model.fit(X, Y, epochs=100)

print(hist.history.keys())

print('100kg 40세 혈중 지방 함량치=', model.predict(np.array([100,40]).reshape(1,2)))
print('60kg 25세 혈중 지방 함량치=', model.predict(np.array([60,25]).reshape(1,2)))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1843.3495
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 1843.3140
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1843.2761
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1843.2401
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1843.2021
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1843.1663
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1843.1283
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1843.0928
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1843.0552
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1843.0188
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1842.9811
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1842.9454
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1842.9077
# Epoch 14/100
# ...

# %%
W_, b_ = model.get_weights()

x = X[:,0]
y = X[:,1]
Z = np.matmul(X, W_) + b_

fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')

Z_reshaped = Z.reshape(25)
ax.scatter(x,y,Z_reshaped, label = 'Predict')

xs = np.array(data[:,0], dtype=np.float32)
ys = np.array(data[:,1], dtype=np.float32)
zs = np.array(data[:,2], dtype=np.float32)
ax.scatter(xs, ys, zs, label = 'Real')
ax.set_xlabel('weight')
ax.set_ylabel('age')
ax.set_zlabel('blood fat')
ax.view_init(15, 15)
plt.legend(loc = 'upper center')
plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Input
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import optimizers

X = np.array([-12, -10,-8,-6,-4,-2,2,4,6,8,10,12])
Y = np.array([144,100,64,36,16,4,4,16,36,64,100,144])

model = Sequential()
model.add(Input(shape = (1,)))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))

model.compile(loss='mse', optimizer = optimizers.Adam(learning_rate = 0.01))

model.fit(X,Y, epochs=500, verbose=2)

test_arr = np.array([-11, -5, -3, 3, 5, 7, 10])
predictions = model.predict(test_arr)

for i, test_value in enumerate(test_arr):
    print(f"Input: {test_value}, Predicted Square: {predictions[i][0]}")
# Out:
# Epoch 1/500
# 1/1 - 1s - 793ms/step - loss: 6264.8008
# Epoch 2/500
# 1/1 - 0s - 44ms/step - loss: 6207.7017
# Epoch 3/500
# 1/1 - 0s - 43ms/step - loss: 6155.4272
# Epoch 4/500
# 1/1 - 0s - 47ms/step - loss: 6110.5376
# Epoch 5/500
# 1/1 - 0s - 44ms/step - loss: 6069.8501
# Epoch 6/500
# 1/1 - 0s - 44ms/step - loss: 6032.6655
# Epoch 7/500
# 1/1 - 0s - 37ms/step - loss: 6001.0835
# Epoch 8/500
# 1/1 - 0s - 39ms/step - loss: 5981.7305
# Epoch 9/500
# 1/1 - 0s - 38ms/step - loss: 5962.3945
# Epoch 10/500
# 1/1 - 0s - 43ms/step - loss: 5942.7583
# Epoch 11/500
# 1/1 - 0s - 40ms/step - loss: 5922.7129
# Epoch 12/500
# 1/1 - 0s - 45ms/step - loss: 5902.1323
# Epoch 13/500
# 1/1 - 0s - 40ms/step - loss: 5881.1914
# Epoch 14/500
# 1/1 - 0s - 37ms/step - loss: 5863.0054
# Epoch 15/500
# 1/1 - 0s - 36ms/step - loss: 5844.1460
# Epoch 16/500
# 1/1 - 0s - 36ms/step - loss: 5823.8242
# Epoch 17/500
# 1/1 - 0s - 36ms/step - loss: 5801.9692
# Epoch 18/500
# 1/1 - 0s - 37ms/step - loss: 5778.5024
# ...

# %%
# 9장 신경망에서 딥러닝으로

# 테스트 데이터의 실제 정답(제곱값) 계산
actual_squares = test_arr ** 2

# 그래프를 깔끔하게 선으로 긋기 위해 X값 기준으로 오름차순 정렬
sorted_indices = np.argsort(test_arr)
test_arr_sorted = test_arr[sorted_indices]
actual_sorted = actual_squares[sorted_indices]
pred_sorted = predictions[sorted_indices].flatten()  # 2차원 배열을 1차원으로 평탄화

plt.figure(figsize=(10, 6))

# 1. 실제 정답 (파란색 점선과 동그라미)
plt.plot(
    test_arr_sorted,
    actual_sorted,
    marker='o',
    color='blue',
    linestyle='dashed',
    label='Actual Square (y = x²)',
    markersize=8,
)

# 2. 딥러닝 예측값 (빨간색 실선과 별 마커)
plt.plot(
    test_arr_sorted,
    pred_sorted,
    marker='*',
    color='red',
    linestyle='solid',
    label='Predicted Square',
    markersize=12,
)

# 3. 실제값과 예측값의 차이(오차)를 보여주는 세로선 추가
for i in range(len(test_arr_sorted)):
    plt.plot(
        [test_arr_sorted[i], test_arr_sorted[i]],
        [actual_sorted[i], pred_sorted[i]],
        color='gray',
        linestyle=':',
        alpha=0.7,
    )

# 꾸미기 요소
plt.xlabel('Test Input (X)', fontsize=12)
plt.ylabel('Value (Y)', fontsize=12)
plt.title(
    'Test Data Comparison: Actual vs Predicted Squares',
    fontsize=14,
    fontweight='bold',
)
plt.xticks(test_arr_sorted)  # X축 눈금을 우리가 테스트한 X값들로만 표시
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
import pandas as pd

# %%
s = pd.Series([9904312,3448737,2890451,2466052])

# %%
print(s)
print(type(s))
# Out:
# 0    9904312
# 1    3448737
# 2    2890451
# 3    2466052
# dtype: int64
# <class 'pandas.Series'>

# %%
print(s.values)
print(type(s.values))
# Out:
# [9904312 3448737 2890451 2466052]
# <class 'numpy.ndarray'>

# %%
s = pd.Series([9904312,3448737,2890451,2466052], index = ['서울', '부산', '인천', '대구'])
print(s)
s.index
print(type(s.index))
print(type(s.values))
# Out:
# 서울    9904312
# 부산    3448737
# 인천    2890451
# 대구    2466052
# dtype: int64
# <class 'pandas.Index'>
# <class 'numpy.ndarray'>

# %%
s.name = "인구 분석"
s.index.name = "도시"
print(s)
print(s.name)
print(s.index.name)
# Out:
# 도시
# 서울    9904312
# 부산    3448737
# 인천    2890451
# 대구    2466052
# Name: 인구 분석, dtype: int64
# 인구 분석
# 도시

# %%
s/1000000
# Out:
# 도시
# 서울    9.904312
# 부산    3.448737
# 인천    2.890451
# 대구    2.466052
# Name: 인구 분석, dtype: float64

# %%
print(s.iloc[1], s["부산"])
print(s.iloc[3], s['대구'])
# Out:
# 3448737 3448737
# 2466052 2466052

# %%
s.iloc[[0,3,1]]
# Out:
# 도시
# 서울    9904312
# 대구    2466052
# 부산    3448737
# Name: 인구 분석, dtype: int64

# %%
print(100e-1)
print(100e2)
# Out:
# 10.0
# 10000.0

# %%
s[  (250e4 < s) & (s < 500e4)]
# Out:
# 도시
# 부산    3448737
# 인천    2890451
# Name: 인구 분석, dtype: int64

# %%
s[1:3]
# Out:
# 도시
# 부산    3448737
# 인천    2890451
# Name: 인구 분석, dtype: int64

# %%
s["부산":"대구"]
# Out:
# 도시
# 부산    3448737
# 인천    2890451
# 대구    2466052
# Name: 인구 분석, dtype: int64

# %%
print("서울" in s)
print("대전" in s)
# Out:
# True
# False

# %%
for data in s.items():
    print(data)
# Out:
# ('서울', 9904312)
# ('부산', 3448737)
# ('인천', 2890451)
# ('대구', 2466052)

# %%
for k, v in s.items():
    print("%s = %d" %(k,v))
# Out:
# 서울 = 9904312
# 부산 = 3448737
# 인천 = 2890451
# 대구 = 2466052

# %%
import pandas as pd
s2 = pd.Series({"서울": 9631482, "부산": 3393191, "인천": 2632035, "대전": 1490158})
s2
# Out:
# 서울    9631482
# 부산    3393191
# 인천    2632035
# 대전    1490158
# dtype: int64

# %%
import pandas as pd
s2 = pd.Series({"서울": 9631482, "부산": 3393191, "인천": 2632035, "대전": 1490158},
               index = ["부산", "서울", "인천", "대전"])

type(s2)
s2
# Out:
# 부산    3393191
# 서울    9631482
# 인천    2632035
# 대전    1490158
# dtype: int64

# %%
ds = s - s2
ds
# Out:
# 도시
# 대구         NaN
# 대전         NaN
# 부산     55546.0
# 서울    272830.0
# 인천    258416.0
# dtype: float64

# %%
s.values- s2.values
# Out:
# array([ 6511121, -6182745,   258416,   975894])

# %%
ds.notnull()
# Out:
# 도시
# 대구    False
# 대전    False
# 부산     True
# 서울     True
# 인천     True
# dtype: bool

# %%
rs = (s-s2) / s2*100
rs
# Out:
# 도시
# 대구         NaN
# 대전         NaN
# 부산    1.636984
# 서울    2.832690
# 인천    9.818107
# dtype: float64

# %%
rs = rs[rs.notnull()]
rs
# Out:
# 도시
# 부산    1.636984
# 서울    2.832690
# 인천    9.818107
# dtype: float64

# %%
rs["부산"] = 1.63
rs["대구"] = 1.41
rs
# Out:
# 도시
# 부산    1.630000
# 서울    2.832690
# 인천    9.818107
# 대구    1.410000
# dtype: float64

# %%
del rs["서울"]
rs
# Out:
# 도시
# 부산    1.630000
# 인천    9.818107
# 대구    1.410000
# dtype: float64

# %%
data = [['John', 28, 'Male'],
        ['Kate', 23, 'Female'],
        ['David', 31, 'Male'],
        ['Emily', 27, 'Female']]
columns = ['Name', 'Age', 'Gender']

df = pd.DataFrame(data, columns = columns)
print(df)
# Out:
#     Name  Age  Gender
# 0   John   28    Male
# 1   Kate   23  Female
# 2  David   31    Male
# 3  Emily   27  Female

# %%
print(df.values)
print(df.columns)
print(df.index)
# Out:
# [['John' 28 'Male']
#  ['Kate' 23 'Female']
#  ['David' 31 'Male']
#  ['Emily' 27 'Female']]
# Index(['Name', 'Age', 'Gender'], dtype='str')
# RangeIndex(start=0, stop=4, step=1)

# %%
print(type(df.values))
print(type(df.columns))
print(type(df.index))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.Index'>
# <class 'pandas.RangeIndex'>

# %%
print(df["Name"])
# Out:
# 0     John
# 1     Kate
# 2    David
# 3    Emily
# Name: Name, dtype: str

# %%
print(df["Name"][0])
# Out:
# John
