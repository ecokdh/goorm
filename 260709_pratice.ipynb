# %%
import random

answer = random.randint(1,10)
count = 0

while True:
    guess = int(input("1부터 10 사이 숫자를 맞혀보세요: "))
    count += 1
    
    if answer == guess:
        print("정답입니다!")
        print("시도 횟수: ", count)
        break

    elif guess < answer:
        print("더 큰 숫자입니다.")

    else:
        print("더 작은 숫자입니다.")
# Out:
# 더 작은 숫자입니다.
# 더 작은 숫자입니다.
# 더 큰 숫자입니다.
# 정답입니다!
# 시도 횟수:  4

# %%
for i in range(1,6):
    print(i, end = " ")
# Out:
# 1 2 3 4 5

# %%
for i in range(5,0,-1):
    print(i, end = " ")
print()
# Out:
# 5 4 3 2 1

# %%
fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
    print(f"과일: {fruit}")
# Out:
# 과일: apple
# 과일: banana
# 과일: cherry

# %%
for char in "Python":
    print(char, end = "-")
# Out:
# P-y-t-h-o-n-

# %%
fruits = ['apple', 'banana', 'cherry']
for idx, fruit in enumerate(fruits, start = 1):
    print(f"{idx}번째: {fruit}")
# Out:
# 1번째: apple
# 2번째: banana
# 3번째: cherry

# %%
names = ['홍길동', '이순신', '김유신']
scores = [85, 92, 78]

for data in zip(names, scores):
    print(data)

for name, score in zip(names, scores):
    print(f"{name}: {score}점")
# Out:
# ('홍길동', 85)
# ('이순신', 92)
# ('김유신', 78)
# 홍길동: 85점
# 이순신: 92점
# 김유신: 78점

# %%
student = {"국어": 90, "영어": 85, "수학": 92}
print(student["국어"])
student["국어"] = 80
print(student)

for subject, score in student.items():
    print(f"{subject}: {score}점")
print(f"평균: {sum(student.values()) / len(student):.1f}점")
# Out:
# 90
# {'국어': 80, '영어': 85, '수학': 92}
# 국어: 80점
# 영어: 85점
# 수학: 92점
# 평균: 85.7점

# %%
def disp():
    print("hello")
    

for i in range(3):
    disp()
# Out:
# hello
# hello
# hello

# %%
def disp1():
    """인사를 출력하는 간단한 함수"""
    print("Hello!")

disp1()
help(disp1)
# Out:
# Hello!
# Help on function disp1 in module __main__:
#
# disp1()
#     인사를 출력하는 간단한 함수

# %%
def add(a, b):
    print(a+b)

add(10,20)
# Out:
# 30

# %%
def greet_person(name):
    print(f"안녕하세요, {name}님!")

greet_person("홍길동")
greet_person("이순신")
# Out:
# 안녕하세요, 홍길동님!
# 안녕하세요, 이순신님!

# %%
def add(a, b):
    return a + b

print(add(1,2))
data = add(10,20)
print(data)
data1 = add(-1, 50)
rlt = data + data1
print(rlt)
# Out:
# 3
# 30
# 79

# %%
def multiply(a,b,c):
    return a * b * c

a1, b1, c1 = map(int, input('세 수를 입력하세요: ').split())
rlt = multiply(a1, b1, c1)
print(rlt)
# Out:
# 125

# %%
def add_mul(a,b):
    return a+b, a*b

a1, b1 = map(int, input('두 수를 입력하세요: ').split())
rlt1, rlt2 = add_mul(a1, b1)
print(rlt1, rlt2)
# Out:
# 30 200

# %%
def find_max(a, b, c):
    max = a
    if b > max:
        max = b
    elif c > max:
        max = c
    return max

a1, b1, c1 = map(int, input("세 수를 입력하세요: ").split())
rlt = find_max(a1, b1, c1)
print(rlt)
# Out:
# 10

# %%
def cal(a, b, c):
    if b == "+":
        return a + c
    elif b == "-":
        return a - c
         
    elif b == "*":
        return a * c
           
    elif b == "/":
        if c == 0:
            return print("0으로 나눌 수 없습니다.")
        return a / c
    else:
        return print("올바른 연산자를 입력하세요.")
    
while True:
    a1 = int(input("첫 번째 숫자 입력: "))
    b1 = input("연산자 입력(+,-,*,/): ")

    if b1 == '종료':
        print("종료합니다.")
        break

    c1 = int(input("두 번째 숫자 입력: "))

    rlt = cal(a1,b1,c1)

    print(f"게산결과: {rlt}")
# Out:
# 0으로 나눌 수 없습니다.
# 게산결과: None
# 게산결과: 5.0
# 종료합니다.
